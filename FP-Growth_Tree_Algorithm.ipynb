# %%
# FP_tree的类定义
class treeNode:
    def __init__(self, nameValue, numOccur, parentNode):
        self.name = nameValue #节点名字
        self.count = numOccur #节点计数值
        self.nodeLink = None #用于链接相似的元素项
        self.parent = parentNode      #needs to be updated
        self.children = {} #子节点

    def inc(self, numOccur):
        '''
        对count变量增加给定值
        '''
        self.count += numOccur

    def disp(self, ind=1):
        '''
        将树以文本形式展示
        '''
        print ('  '*ind, self.name, ' ', self.count)
        for child in self.children.values():
            child.disp(ind+1)

# FP_tree构建函数
def createTree(dataSet, minSup=1):
    '''
    创建FP树
    '''
    headerTable = {}
    #第一次扫描数据集
    for trans in dataSet:#计算item出现频数
        for item in trans:
            headerTable[item] = headerTable.get(item, 0) + dataSet[trans]
    headerTable = {k:v for k,v in headerTable.items() if v >= minSup}
    freqItemSet = set(headerTable.keys())
    #print ('freqItemSet: ',freqItemSet)
    if len(freqItemSet) == 0: return None, None  #如果没有元素项满足要求，则退出
    for k in headerTable:
        headerTable[k] = [headerTable[k], None] #初始化headerTable
    #print ('headerTable: ',headerTable)
    #第二次扫描数据集
    retTree = treeNode('Null Set', 1, None) #创建树
    for tranSet, count in dataSet.items():  
        localD = {}
        for item in tranSet:  #put transaction items in order
            if item in freqItemSet:
                localD[item] = headerTable[item][0]
        if len(localD) > 0:
            orderedItems = [v[0] for v in sorted(localD.items(), key=lambda p: p[1], reverse=True)]
            updateTree(orderedItems, retTree, headerTable, count)#将排序后的item集合填充的树中
    return retTree, headerTable #返回树型结构和头指针表

def updateTree(items, inTree, headerTable, count):
    if items[0] in inTree.children:#检查第一个元素项是否作为子节点存在
        inTree.children[items[0]].inc(count) #存在，更新计数
    else:   #不存在，创建一个新的treeNode,将其作为一个新的子节点加入其中
        inTree.children[items[0]] = treeNode(items[0], count, inTree)
        if headerTable[items[0]][1] == None: #更新头指针表
            headerTable[items[0]][1] = inTree.children[items[0]]
        else:
            updateHeader(headerTable[items[0]][1], inTree.children[items[0]])
    if len(items) > 1:#不断迭代调用自身，每次调用都会删掉列表中的第一个元素
        updateTree(items[1::], inTree.children[items[0]], headerTable, count)

def updateHeader(nodeToTest, targetNode):
    '''
    this version does not use recursion
    Do not use recursion to traverse a linked list!
    更新头指针表，确保节点链接指向树中该元素项的每一个实例
    '''
    while (nodeToTest.nodeLink != None):    
        nodeToTest = nodeToTest.nodeLink
    nodeToTest.nodeLink = targetNode

# 抽取条件模式基
def ascendTree(leafNode, prefixPath): #迭代上溯整棵树
    if leafNode.parent != None:
        prefixPath.append(leafNode.name)
        ascendTree(leafNode.parent, prefixPath)

def findPrefixPath(basePat, treeNode): #treeNode comes from header table
    condPats = {}
    while treeNode != None:
        prefixPath = []
        ascendTree(treeNode, prefixPath)
        if len(prefixPath) > 1: 
            condPats[frozenset(prefixPath[1:])] = treeNode.count
        treeNode = treeNode.nodeLink
    return condPats

# 递归查找频繁项集
def mineTree(inTree, headerTable, minSup, preFix, freqItemList):
    bigL = [v[0] for v in sorted(headerTable.items(), key=lambda p: p[1][0])]# 1.排序头指针表
    for basePat in bigL:  #从头指针表的底端开始
        newFreqSet = preFix.copy()
        newFreqSet.add(basePat)
        print ('finalFrequent Item: ',newFreqSet)    #添加的频繁项列表
        freqItemList.append(newFreqSet)
        condPattBases = findPrefixPath(basePat, headerTable[basePat][1])
        print ('condPattBases :',basePat, condPattBases)
        # 2.从条件模式基创建条件FP树
        myCondTree, myHead = createTree(condPattBases, minSup)
#         print ('head from conditional tree: ', myHead)
        if myHead != None: # 3.挖掘条件FP树
            print ('conditional tree for: ',newFreqSet)
            myCondTree.disp(1)            
            mineTree(myCondTree, myHead, minSup, newFreqSet, freqItemList)

# %%
# 测试1
def loadSimpDat():
    simpDat = [
                ['I1','I2','I5'],
                ['I2','I4'],
                ['I2','I3'],
                ['I1','I2','I4'],
                ['I1','I3'],
                ['I2','I3'],
                ['I1','I3'],
                ['I1','I2','I3','I5'],
                ['I1','I2','I3']
              ]
    return simpDat

def createInitSet(dataSet):  
    retDict = {}  
    for trans in dataSet:  
        retDict[frozenset(trans)] = retDict.get(frozenset(trans), 0) + 1 #若没有相同事项，则为1；若有相同事项，则加1  
    return retDict

minSup = 2
simpDat = loadSimpDat()
initSet = createInitSet(simpDat)
myFPtree, myHeaderTab = createTree(initSet, minSup)
myFPtree.disp()
myFreqList = []
mineTree(myFPtree, myHeaderTab, minSup, set([]), myFreqList)

myFreqList
# Out:
#    Null Set   1
#      I2   7
#        I1   4
#          I5   1
#          I4   1
#          I3   2
#            I5   1
#        I4   1
#        I3   2
#      I1   2
#        I3   2
# finalFrequent Item:  {'I5'}
# condPattBases : I5 {frozenset({'I2', 'I1'}): 1, frozenset({'I2', 'I1', 'I3'}): 1}
# conditional tree for:  {'I5'}
#    Null Set   1
#      I2   2
#        I1   2
# finalFrequent Item:  {'I5', 'I2'}
# condPattBases : I2 {}
# finalFrequent Item:  {'I5', 'I1'}
# condPattBases : I1 {frozenset({'I2'}): 2}
# conditional tree for:  {'I5', 'I1'}
#    Null Set   1
#      I2   2
# finalFrequent Item:  {'I5', 'I1', 'I2'}
# condPattBases : I2 {}
# finalFrequent Item:  {'I4'}
# condPattBases : I4 {frozenset({'I2'}): 1, frozenset({'I2', 'I1'}): 1}
# conditional tree for:  {'I4'}
#    Null Set   1
#      I2   2
# finalFrequent Item:  {'I2', 'I4'}
# condPattBases : I2 {}
# finalFrequent Item:  {'I1'}
# condPattBases : I1 {frozenset({'I2'}): 4}
# conditional tree for:  {'I1'}
#    Null Set   1
#      I2   4
# finalFrequent Item:  {'I2', 'I1'}
# condPattBases : I2 {}
# finalFrequent Item:  {'I3'}
# condPattBases : I3 {frozenset({'I2'}): 2, frozenset({'I1'}): 2, frozenset({'I2', 'I1'}): 2}
# conditional tree for:  {'I3'}
#    Null Set   1
#      I2   4
#        I1   2
#      I1   2
# finalFrequent Item:  {'I2', 'I3'}
# condPattBases : I2 {}
# finalFrequent Item:  {'I1', 'I3'}
# condPattBases : I1 {frozenset({'I2'}): 2}
# conditional tree for:  {'I1', 'I3'}
#    Null Set   1
#      I2   2
# finalFrequent Item:  {'I2', 'I1', 'I3'}
# condPattBases : I2 {}
# finalFrequent Item:  {'I2'}
# condPattBases : I2 {}
# [{'I5'},
#  {'I2', 'I5'},
#  {'I1', 'I5'},
#  {'I1', 'I2', 'I5'},
#  {'I4'},
#  {'I2', 'I4'},
#  {'I1'},
#  {'I1', 'I2'},
#  {'I3'},
#  {'I2', 'I3'},
#  {'I1', 'I3'},
#  {'I1', 'I2', 'I3'},
#  {'I2'}]

# %%
# 测试2
def loadSimpDat():
    simpDat = [['r', 'z', 'h', 'j', 'p'],
               ['z', 'y', 'x', 'w', 'v', 'u', 't', 's'],
               ['z'],
               ['r', 'x', 'n', 'o', 's'],
            #    ['r', 'x', 'n', 'o', 's'],
               ['y', 'r', 'x', 'z', 'q', 't', 'p'],
               ['y', 'z', 'x', 'e', 'q', 's', 't', 'm']]
    return simpDat

def createInitSet(dataSet):  
    retDict = {}  
    for trans in dataSet:  
        retDict[frozenset(trans)] = retDict.get(frozenset(trans), 0) + 1 #若没有相同事项，则为1；若有相同事项，则加1  
    return retDict

minSup = 2
simpDat = loadSimpDat()
initSet = createInitSet(simpDat)
myFPtree, myHeaderTab = createTree(initSet, minSup)
myFPtree.disp()
myFreqList = []
mineTree(myFPtree, myHeaderTab, minSup, set([]), myFreqList)

myFreqList
# Out:
#    Null Set   1
#      z   5
#        r   1
#          p   1
#        x   3
#          t   3
#            y   3
#              s   2
#                q   1
#              r   1
#                q   1
#                  p   1
#      x   1
#        r   1
#          s   1
# finalFrequent Item:  {'p'}
# condPattBases : p {frozenset({'r', 'z'}): 1, frozenset({'t', 'q', 'x', 'z', 'y', 'r'}): 1}
# conditional tree for:  {'p'}
#    Null Set   1
#      r   1
#        z   1
#      z   1
#        r   1
# finalFrequent Item:  {'p', 'r'}
# condPattBases : r {frozenset({'z'}): 1}
# finalFrequent Item:  {'p', 'z'}
# condPattBases : z {frozenset({'r'}): 1}
# finalFrequent Item:  {'q'}
# condPattBases : q {frozenset({'t', 'x', 'z', 'y', 'r'}): 1, frozenset({'t', 'x', 'z', 'y', 's'}): 1}
# conditional tree for:  {'q'}
#    Null Set   1
#      t   2
#        x   2
#          z   2
#            y   2
# finalFrequent Item:  {'t', 'q'}
# condPattBases : t {}
# finalFrequent Item:  {'x', 'q'}
# condPattBases : x {frozenset({'t'}): 2}
# conditional tree for:  {'x', 'q'}
#    Null Set   1
#      t   2
# finalFrequent Item:  {'x', 'q', 't'}
# condPattBases : t {}
# finalFrequent Item:  {'z', 'q'}
# condPattBases : z {frozenset({'x', 't'}): 2}
# conditional tree for:  {'z', 'q'}
#    Null Set   1
#      x   2
#        t   2
# finalFrequent Item:  {'x', 'z', 'q'}
# condPattBases : x {}
# finalFrequent Item:  {'t', 'z', 'q'}
# condPattBases : t {frozenset({'x'}): 2}
# conditional tree for:  {'t', 'z', 'q'}
#    Null Set   1
#      x   2
# finalFrequent Item:  {'t', 'z', 'q', 'x'}
# condPattBases : x {}
# finalFrequent Item:  {'y', 'q'}
# condPattBases : y {frozenset({'x', 'z', 't'}): 2}
# conditional tree for:  {'y', 'q'}
#    Null Set   1
#      x   2
#        z   2
#          t   2
# finalFrequent Item:  {'y', 'q', 'x'}
# condPattBases : x {}
# finalFrequent Item:  {'y', 'z', 'q'}
# condPattBases : z {frozenset({'x'}): 2}
# conditional tree for:  {'y', 'z', 'q'}
#    Null Set   1
#      x   2
# finalFrequent Item:  {'y', 'z', 'q', 'x'}
# condPattBases : x {}
# finalFrequent Item:  {'y', 'q', 't'}
# condPattBases : t {frozenset({'x', 'z'}): 2}
# conditional tree for:  {'y', 'q', 't'}
#    Null Set   1
#      x   2
#        z   2
# finalFrequent Item:  {'y', 'q', 'x', 't'}
# condPattBases : x {}
# finalFrequent Item:  {'y', 'z', 'q', 't'}
# condPattBases : z {frozenset({'x'}): 2}
# conditional tree for:  {'y', 'z', 'q', 't'}
#    Null Set   1
#      x   2
# finalFrequent Item:  {'t', 'q', 'x', 'z', 'y'}
# condPattBases : x {}
# finalFrequent Item:  {'r'}
# condPattBases : r {frozenset({'z'}): 1, frozenset({'x'}): 1, frozenset({'y', 'z', 'x', 't'}): 1}
# conditional tree for:  {'r'}
#    Null Set   1
#      z   2
#        x   1
#      x   1
# finalFrequent Item:  {'r', 'z'}
# condPattBases : z {}
# finalFrequent Item:  {'x', 'r'}
# condPattBases : x {frozenset({'z'}): 1}
# finalFrequent Item:  {'t'}
# condPattBases : t {frozenset({'x', 'z'}): 3}
# conditional tree for:  {'t'}
#    Null Set   1
#      x   3
#        z   3
# finalFrequent Item:  {'t', 'x'}
# condPattBases : x {}
# finalFrequent Item:  {'t', 'z'}
# condPattBases : z {frozenset({'x'}): 3}
# conditional tree for:  {'t', 'z'}
#    Null Set   1
#      x   3
# finalFrequent Item:  {'t', 'z', 'x'}
# condPattBases : x {}
# finalFrequent Item:  {'y'}
# condPattBases : y {frozenset({'t', 'z', 'x'}): 3}
# conditional tree for:  {'y'}
#    Null Set   1
#      t   3
#        z   3
#          x   3
# finalFrequent Item:  {'y', 't'}
# condPattBases : t {}
# finalFrequent Item:  {'y', 'z'}
# condPattBases : z {frozenset({'t'}): 3}
# conditional tree for:  {'y', 'z'}
#    Null Set   1
#      t   3
# finalFrequent Item:  {'y', 'z', 't'}
# condPattBases : t {}
# finalFrequent Item:  {'y', 'x'}
# condPattBases : x {frozenset({'t', 'z'}): 3}
# conditional tree for:  {'y', 'x'}
#    Null Set   1
#      t   3
#        z   3
# finalFrequent Item:  {'y', 'x', 't'}
# condPattBases : t {}
# finalFrequent Item:  {'y', 'z', 'x'}
# condPattBases : z {frozenset({'t'}): 3}
# conditional tree for:  {'y', 'z', 'x'}
#    Null Set   1
#      t   3
# finalFrequent Item:  {'y', 'z', 'x', 't'}
# condPattBases : t {}
# finalFrequent Item:  {'s'}
# condPattBases : s {frozenset({'y', 'z', 'x', 't'}): 2, frozenset({'x', 'r'}): 1}
# conditional tree for:  {'s'}
#    Null Set   1
#      x   3
#        y   2
#          z   2
#            t   2
# finalFrequent Item:  {'y', 's'}
# condPattBases : y {frozenset({'x'}): 2}
# conditional tree for:  {'y', 's'}
#    Null Set   1
#      x   2
# finalFrequent Item:  {'y', 's', 'x'}
# condPattBases : x {}
# finalFrequent Item:  {'s', 'z'}
# condPattBases : z {frozenset({'y', 'x'}): 2}
# conditional tree for:  {'s', 'z'}
#    Null Set   1
#      y   2
#        x   2
# finalFrequent Item:  {'y', 's', 'z'}
# condPattBases : y {}
# finalFrequent Item:  {'x', 's', 'z'}
# condPattBases : x {frozenset({'y'}): 2}
# conditional tree for:  {'x', 's', 'z'}
#    Null Set   1
#      y   2
# finalFrequent Item:  {'x', 'y', 's', 'z'}
# condPattBases : y {}
# finalFrequent Item:  {'t', 's'}
# condPattBases : t {frozenset({'y', 'z', 'x'}): 2}
# conditional tree for:  {'t', 's'}
#    Null Set   1
#      y   2
#        z   2
#          x   2
# finalFrequent Item:  {'t', 's', 'y'}
# condPattBases : y {}
# finalFrequent Item:  {'t', 's', 'z'}
# condPattBases : z {frozenset({'y'}): 2}
# conditional tree for:  {'t', 's', 'z'}
#    Null Set   1
#      y   2
# finalFrequent Item:  {'t', 'y', 's', 'z'}
# condPattBases : y {}
# finalFrequent Item:  {'t', 's', 'x'}
# condPattBases : x {frozenset({'y', 'z'}): 2}
# conditional tree for:  {'t', 's', 'x'}
#    Null Set   1
#      y   2
#        z   2
# finalFrequent Item:  {'t', 's', 'y', 'x'}
# condPattBases : y {}
# finalFrequent Item:  {'t', 's', 'z', 'x'}
# condPattBases : z {frozenset({'y'}): 2}
# conditional tree for:  {'t', 's', 'z', 'x'}
#    Null Set   1
#      y   2
# finalFrequent Item:  {'x', 'y', 'z', 't', 's'}
# condPattBases : y {}
# finalFrequent Item:  {'x', 's'}
# condPattBases : x {}
# finalFrequent Item:  {'x'}
# condPattBases : x {frozenset({'z'}): 3}
# conditional tree for:  {'x'}
#    Null Set   1
#      z   3
# finalFrequent Item:  {'x', 'z'}
# condPattBases : z {}
# finalFrequent Item:  {'z'}
# condPattBases : z {}
# [{'p'},
#  {'p', 'r'},
#  {'p', 'z'},
#  {'q'},
#  {'q', 't'},
#  {'q', 'x'},
#  {'q', 't', 'x'},
#  {'q', 'z'},
#  {'q', 'x', 'z'},
#  {'q', 't', 'z'},
#  {'q', 't', 'x', 'z'},
#  {'q', 'y'},
#  {'q', 'x', 'y'},
#  {'q', 'y', 'z'},
#  {'q', 'x', 'y', 'z'},
#  {'q', 't', 'y'},
#  {'q', 't', 'x', 'y'},
#  {'q', 't', 'y', 'z'},
#  {'q', 't', 'x', 'y', 'z'},
#  {'r'},
#  {'r', 'z'},
#  {'r', 'x'},
#  {'t'},
#  {'t', 'x'},
#  {'t', 'z'},
#  {'t', 'x', 'z'},
#  {'y'},
#  {'t', 'y'},
#  {'y', 'z'},
#  {'t', 'y', 'z'},
#  {'x', 'y'},
#  {'t', 'x', 'y'},
#  {'x', 'y', 'z'},
#  {'t', 'x', 'y', 'z'},
#  {'s'},
#  {'s', 'y'},
#  {'s', 'x', 'y'},
#  {'s', 'z'},
#  {'s', 'y', 'z'},
#  {'s', 'x', 'z'},
#  {'s', 'x', 'y', 'z'},
#  {'s', 't'},
#  {'s', 't', 'y'},
#  {'s', 't', 'z'},
#  {'s', 't', 'y', 'z'},
#  {'s', 't', 'x'},
#  {'s', 't', 'x', 'y'},
#  {'s', 't', 'x', 'z'},
#  {'s', 't', 'x', 'y', 'z'},
#  {'s', 'x'},
#  {'x'},
#  {'x', 'z'},
#  {'z'}]
